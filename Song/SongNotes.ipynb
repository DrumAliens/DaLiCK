# %% [markdown]
# ## Kick off the ChucK scripts

# %%
! ./00_StartSong.py

# %% [markdown]
# ## Sound check - start

# %%
# !! ./11_Kick.py h66 & ./12_Snare.py h66 & ./13_Cymbals.py h66 & ./21_Chop.py & ./22_Chop.py & ./23_Chop.py & ./24_Chop.py & ./25_Chop.py & ./26_Chop.py & ./27_Chop.py & ./28_Chop.py & ./41_Guitar.py p1 & ./31_Piano.py p1
# Out:
# []

# %% [markdown]
# ## Sound check - stop

# %%
# !! ./11_Kick.py s1 & ./12_Snare.py s1 & ./13_Cymbals.py s1 & ./21_Chop.py s1 & ./22_Chop.py s1 & ./23_Chop.py s1 & ./24_Chop.py s1 & ./25_Chop.py s1 & ./26_Chop.py s1 & ./27_Chop.py s1 & ./28_Chop.py s1 & ./41_Guitar.py s1 & ./31_Piano.py s1
# Out:
# []

# %% [markdown]
# # **Barstardisation of theme by Duston Brown**

# %%
# !! ./23_Chop.py
# Out:
# []

# %%
# !! ./21_Chop.py m11 & ./25_Chop.py m11
# Out:
# []

# %%
# !! ./24_Chop.py m12 & ./27_Chop.py m8
# Out:
# []

# %%
# !! ./21_Chop.py & ./22_Chop.py c0.7 & ./24_Chop.py c0.7 & ./25_Chop.py c0.7 & ./26_Chop.py c0.7 & ./27_Chop.py c0.7 & ./28_Chop.py c0.7
# Out:
# []

# %% [markdown]
# ## Bring in the drums

# %%
! ./13_Cymbals.py p3 r1 & ./11_Kick.py h66 W9.92 & ./12_Snare.py c0.8 h66 w9.92 v0.5 & ./13_Cymbals.py h66 w9.92

# %% [markdown]
# #### Guitar

# %%
# !! ./41_Guitar.py p1
# Out:
# []

# %%
# !! ./41_Guitar.py p2
# Out:
# []

# %% [markdown]
# #### Cycle Round Chords

# %%
# !! ./41_Guitar.py p1 & ./41_Guitar.py p2 w19.84
# Out:
# []

# %%
# !! ./41_Guitar.py p1 & ./41_Guitar.py p2 w19.84 & ./31_Piano.py p2 w19.84
# Out:
# []

# %%
# !! ./41_Guitar.py p1 & ./31_Piano.py p1 & ./41_Guitar.py p2 w19.84 & ./31_Piano.py p2 w19.84
# Out:
# []

# %% [markdown]
# #### Fade out to just the piano and bring in the rain also fade out Frogs for later

# %%
# !! ./01_SongFade.py m91 d-30.0 & ./61_Rain.py w20.0
# Out:
# []

# %% [markdown]
# #### Piano chords then hold the last note

# %%
# !! ./31_Piano.py p3 r1
# Out:
# []

# %% [markdown]
# # **FROGS AND RAIN**

# %% [markdown]
# #### Change tempo - check that it has been recognised before going further

# %%
# !! ./00_StartSong.py n32 d4 t146.0
# Out:
# []

# %% [markdown]
# #### Start thunder
#   best approach is to set the right number going and then don't touch until finished can be used as a timer for this section
# - r6 gives 3 min 56 s
# - r7 gives 4 min 36 s
# - r8 gives 5 min 15 s
# - r9 gives 5 min 55 s
# - r10 gives 6 min 34 s
#
# Delay the start of the frogs so don't do all of the changes at the same time

# %%
# !! ./62_Thunder.py r6 v0.03 & ./01_SongFade.py m64 d90.0 w13.1507 & ./71_73_Frogs_Break_LeftRight.py p1 w13.1507
# Out:
# []

# %% [markdown]
# #### Slowly increase sophistication of the introduction of the left and right frogs

# %%
# !! ./71_73_Frogs_Break_LeftRight.py p2
# Out:
# []

# %%
# !! ./71_73_Frogs_Break_LeftRight.py p3
# Out:
# []

# %% [markdown]
# #### Bass drum frog

# %%
# !! ./74_Frogs_Break_Bass.py v0.4 m10
# Out:
# []

# %% [markdown]
# #### Central high pitch frog

# %%
# !! ./72_Frogs_Break_Mid.py p1 c0.8
# Out:
# []

# %%
# !! ./72_Frogs_Break_Mid.py p2 c0.8

# %%
# !! ./72_Frogs_Break_Mid.py p3 c0.8
# Out:
# []

# %% [markdown]
# #### Swap between two levels of rythm on left and right frogs

# %%
# !! ./71_73_Frogs_Break_LeftRight.py p3

# %%
# !! ./71_73_Frogs_Break_LeftRight.py p33
# Out:
# []

# %%
# !! ./71_73_Frogs_Break_LeftRight.py p5
# Out:
# []

# %% [markdown]
# #### Final Thunder
#
# Make sure previous thunders have finished and that any delayed instruments have finished

# %%
# !! ./71_73_Frogs_Break_LeftRight.py s1 & ./74_Frogs_Break_Bass.py s1 & ./72_Frogs_Break_Mid.py s1 & ./62_Thunder.py p2 r1 v0.125
# Out:
# []

# %% [markdown]
# #### Final frog reprise

# %%
# !! ./72_Frogs_Break_Mid.py p10 r3
# Out:
# []

# %% [markdown]
# #### Fade out the rain

# %%
# !! ./01_SongFade.py m32 d-60.0
# Out:
# []
